# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import gmaps
import os
from pprint import pprint
from scipy.stats import linregress
from config import gkey

# %%
cities = '../WeatherPy/cities.csv'
df = pd.read_csv(cities)
df
# Out:
#      Unnamed: 0          City Country  Latitude  Longitude  Temperature  \
# 0             0   yellowknife      CA     62.46    -114.35        64.40
# 1             1  punta arenas      CL    -53.15     -70.92        30.20
# 2             2   mitsamiouli      KM    -11.38      43.28        74.75
# 3             3        atuona      PF     -9.80    -139.03        79.72
# 4             4       kamenka      RU     51.32      42.77        57.00
# ..          ...           ...     ...       ...        ...          ...
# 521         577          suez      EG     29.97      32.53        67.86
# 522         578      lakhipur      IN     26.03      90.30        85.87
# 523         579    strezhevoy      RU     60.73      77.59        60.80
# 524         580        boende      CD     -0.22      20.87        70.61
# 525         582          adre      TD     13.47      22.20        73.63
#
#      Humidity  Cloudiness  Wind Speed          Date
# ...

# %%
drop = ['Unnamed: 0']
df.drop(drop, inplace=True, axis=1)
df
# Out:
#              City Country  Latitude  Longitude  Temperature  Humidity  \
# 0     yellowknife      CA     62.46    -114.35        64.40      48.0
# 1    punta arenas      CL    -53.15     -70.92        30.20      86.0
# 2     mitsamiouli      KM    -11.38      43.28        74.75      72.0
# 3          atuona      PF     -9.80    -139.03        79.72      76.0
# 4         kamenka      RU     51.32      42.77        57.00      79.0
# ..            ...     ...       ...        ...          ...       ...
# 521          suez      EG     29.97      32.53        67.86      81.0
# 522      lakhipur      IN     26.03      90.30        85.87      76.0
# 523    strezhevoy      RU     60.73      77.59        60.80      72.0
# 524        boende      CD     -0.22      20.87        70.61      91.0
# 525          adre      TD     13.47      22.20        73.63      78.0
#
#      Cloudiness  Wind Speed          Date
# 0            40        5.82  1.594954e+09
# ...

# %%
gmaps.configure(api_key = gkey)
location = df[['Latitude', 'Longitude']].astype(float)
humidity = df['Humidity'].astype(float)
figure_layout = {
     'width' : '1000px',
     'height':'400px',
     'border':'1px solid black',
     'padding':'1px',
     'margin':'0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout)
fig = gmaps.figure()

heatmap_layer = gmaps.heatmap_layer(location, weights=humidity, dissipating=False, max_intensity=100, point_radius=5)

fig.add_layer(heatmap_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
ideal_min_temp = df['Temperature'] > 70
ideal_max_temp = df['Temperature'] < 80
ideal_wind = df['Wind Speed'] < 10
ideal_clouds = df['Cloudiness'] == 0
all_ideal = ideal_min_temp & ideal_max_temp & ideal_wind & ideal_clouds

ideal_df = df[all_ideal]
ideal_df.dropna()
ideal_df.reset_index()
ideal_df = pd.DataFrame(ideal_df, columns=['City', 'Country', 'Latitude', 'Longitude', 'Temperature', 'Humidity',
                                          'Cloudiness', 'Wind Speed', 'Date', "Hotel Name"])
ideal_df
# Out:
#                         City Country  Latitude  Longitude  Temperature  \
# 80                      jalu      LY     29.03      21.55        76.23
# 111                    airai      TL     -8.93     125.41        73.18
# 126          emilio carranza      MX     19.97     -96.61        79.43
# 148             todos santos      MX     23.45    -110.22        79.00
# 171             port hedland      AU    -20.32     118.57        78.80
# 189                   lardos      GR     36.09      28.02        77.00
# 264               itupiranga      BR     -5.13     -49.33        75.18
# 285           victoria point      AU    -27.58     153.30        71.01
# 287                   zilair      RU     52.23      57.44        71.56
# 393                   koumac      NC    -20.57     164.28        71.44
# 403  castellammare del golfo      IT     38.02      12.89        79.00
# 438              komsomolets      KZ     53.75      62.07        74.59
# ...

# %%
params = {'radius': 5000, 'types': 'lodging', 'keyword': 'Hotel', 'key': gkey}

for index, row in ideal_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]

    params["location"] = f"{lat},{lng}"

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    name_address = requests.get(base_url, params=params)
    
    print(name_address.url)

    name_address = name_address.json()
    print(json.dumps(name_address, indent=4, sort_keys=True))

    try:
        ideal_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field... skipping.")
ideal_df.info()
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyC2rFYJNGO3JO56uW75478iBMbMQSOr31A&location=29.03%2C21.55
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.03272369999999,
#                     "lng": 21.5458054
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.03416212989272,
#                         "lng": 21.54705467989272
#                     },
#                     "southwest": {
#                         "lat": 29.03146247010728,
#                         "lng": 21.54435502010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in ideal_df.iterrows()]
locations = ideal_df[["Latitude", "Longitude"]]

figure_layout = {
    'width': '900px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout,zoom_level=2,center=(15,25))

hotel_layer = gmaps.marker_layer(
    locations,info_box_content=[info_box_template.format(**row) for index, row in ideal_df.iterrows()]
)

fig.add_layer(heatmap_layer)
fig.add_layer(hotel_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…
